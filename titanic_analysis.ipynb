# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %% [markdown]
# # data loding

# %%
titanic =pd.read_csv("/content/Titanic-Dataset.csv")          #load csv file
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Fare  Port
# 806         0       1    0  39.0      0      0   0.0   1.0
# 815         0       1    0  28.0      0      0   0.0   1.0
# 466         0       2    0  28.0      0      0   0.0   1.0
# 481         0       2    0  28.0      0      0   0.0   1.0
# 822         0       1    0  38.0      0      0   0.0   1.0

# %%
len(titanic)
# Out:
# 891

# %%
titanic.info()              # Summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()           # Statistical summary
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.shape
# Out:
# (891, 12)

# %%
gender_counts=titanic['Sex'].value_counts()
gender_counts
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## DATA PREPROCESSING

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].fillna(titanic['Age'].median(),inplace=True)

# %%
titanic['Fare'].fillna(titanic['Fare'].median(),inplace=True)

# %%
titanic['Cabin'].fillna(titanic['Cabin'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-15-1758515908.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Cabin'].fillna(titanic['Cabin'].mode()[0],inplace=True)

# %%
titanic.duplicated().sum()
# Out:
# np.int64(0)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Dropping irrelevant Columns

# %%
titanic.drop(['PassengerId'], axis=1, inplace=True)
titanic.drop(['Name'], axis=1, inplace=True)
titanic.drop(['Ticket'], axis=1, inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     891 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ## normal slicing     and using iloc

# %%
titanic[400:406]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare    Cabin Embarked
# 400         1       3    male  39.0      0      0   7.9250  B96 B98        S
# 401         0       3    male  26.0      0      0   8.0500  B96 B98        S
# 402         0       3  female  21.0      1      0   9.8250  B96 B98        S
# 403         0       3    male  28.0      1      0  15.8500  B96 B98        S
# 404         0       3  female  20.0      0      0   8.6625  B96 B98        S
# 405         0       2    male  34.0      1      0  21.0000  B96 B98        S

# %%
#display entire dataset     slicing using iloc
titanic.iloc[:]
titanic.iloc[:,:]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare    Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500  B96 B98        S
# 1           1       1  female  38.0      1      0  71.2833      C85        C
# 2           1       3  female  26.0      0      0   7.9250  B96 B98        S
# 3           1       1  female  35.0      1      0  53.1000     C123        S
# 4           0       3    male  35.0      0      0   8.0500  B96 B98        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000  B96 B98        S
# 887         1       1  female  19.0      0      0  30.0000      B42        S
# 888         0       3  female  28.0      1      2  23.4500  B96 B98        S
# 889         1       1    male  26.0      0      0  30.0000     C148        C
# 890         0       3    male  32.0      0      0   7.7500  B96 B98        Q
#
# [891 rows x 9 columns]

# %%
titanic.iloc[2:240,2:]
# Out:
#         Sex   Age  SibSp  Parch     Fare    Cabin Embarked
# 2    female  26.0      0      0   7.9250  B96 B98        S
# 3    female  35.0      1      0  53.1000     C123        S
# 4      male  35.0      0      0   8.0500  B96 B98        S
# 5      male  28.0      0      0   8.4583  B96 B98        Q
# 6      male  54.0      0      0  51.8625      E46        S
# ..      ...   ...    ...    ...      ...      ...      ...
# 235  female  28.0      0      0   7.5500  B96 B98        S
# 236    male  44.0      1      0  26.0000  B96 B98        S
# 237  female   8.0      0      2  26.2500  B96 B98        S
# 238    male  19.0      0      0  10.5000  B96 B98        S
# 239    male  33.0      0      0  12.2750  B96 B98        S
#
# [238 rows x 7 columns]

# %%
titanic.iloc[:, [4, -2, 2, -1, 1, 0]]
# Out:
#      SibSp    Cabin     Sex Embarked  Pclass  Survived
# 0        1  B96 B98    male        S       3         0
# 1        1      C85  female        C       1         1
# 2        0  B96 B98  female        S       3         1
# 3        1     C123  female        S       1         1
# 4        0  B96 B98    male        S       3         0
# ..     ...      ...     ...      ...     ...       ...
# 886      0  B96 B98    male        S       2         0
# 887      0      B42  female        S       1         1
# 888      1  B96 B98  female        S       3         0
# 889      0     C148    male        C       1         1
# 890      0  B96 B98    male        Q       3         0
#
# [891 rows x 6 columns]

# %%
titanic.iloc[800:810],titanic.iloc[880:890]
# Out:
# (     Survived  Pclass     Sex    Age  SibSp  Parch      Fare    Cabin Embarked
#  800         0       2    male  34.00      0      0   13.0000  B96 B98        S
#  801         1       2  female  31.00      1      1   26.2500  B96 B98        S
#  802         1       1    male  11.00      1      2  120.0000  B96 B98        S
#  803         1       3    male   0.42      0      1    8.5167  B96 B98        C
#  804         1       3    male  27.00      0      0    6.9750  B96 B98        S
#  805         0       3    male  31.00      0      0    7.7750  B96 B98        S
#  806         0       1    male  39.00      0      0    0.0000      A36        S
#  807         0       3  female  18.00      0      0    7.7750  B96 B98        S
#  808         0       2    male  39.00      0      0   13.0000  B96 B98        S
#  809         1       1  female  33.00      1      0   53.1000       E8        S,
#       Survived  Pclass     Sex   Age  SibSp  Parch     Fare    Cabin Embarked
# ...

# %% [markdown]
# # sort_values()
# syntax:
#  DataFrame.sort_values(by='column_name', ascending=True)

# %%
titanic.sort_values(by='Age', ascending=True)
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch     Fare    Cabin Embarked
# 803         1       3    male   0.42      0      1   8.5167  B96 B98        C
# 755         1       2    male   0.67      1      1  14.5000  B96 B98        S
# 469         1       3  female   0.75      2      1  19.2583  B96 B98        C
# 644         1       3  female   0.75      2      1  19.2583  B96 B98        C
# 78          1       2    male   0.83      0      2  29.0000  B96 B98        S
# ..        ...     ...     ...    ...    ...    ...      ...      ...      ...
# 116         0       3    male  70.50      0      0   7.7500  B96 B98        Q
# 96          0       1    male  71.00      0      0  34.6542       A5        C
# 493         0       1    male  71.00      0      0  49.5042  B96 B98        C
# 851         0       3    male  74.00      0      0   7.7750  B96 B98        S
# 630         1       1    male  80.00      0      0  30.0000      A23        S
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by=['Pclass', 'Fare'], ascending=[True, False])
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare        Cabin  \
# 258         1       1  female  35.0      0      0  512.3292      B96 B98
# 679         1       1    male  36.0      0      1  512.3292  B51 B53 B55
# 737         1       1    male  35.0      0      0  512.3292         B101
# 27          0       1    male  19.0      3      2  263.0000  C23 C25 C27
# 88          1       1  female  23.0      3      2  263.0000  C23 C25 C27
# ..        ...     ...     ...   ...    ...    ...       ...          ...
# 378         0       3    male  20.0      0      0    4.0125      B96 B98
# 179         0       3    male  36.0      0      0    0.0000      B96 B98
# 271         1       3    male  25.0      0      0    0.0000      B96 B98
# 302         0       3    male  19.0      0      0    0.0000      B96 B98
# 597         0       3    male  49.0      0      0    0.0000      B96 B98
#
#     Embarked
# 258        C
# 679        C
# 737        C
# 27         S
# 88         S
# ...

# %%
titanic.sort_values(by='Fare', ascending=False, inplace=True)
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare        Cabin  \
# 679         1       1    male  36.0      0      1  512.3292  B51 B53 B55
# 258         1       1  female  35.0      0      0  512.3292      B96 B98
# 737         1       1    male  35.0      0      0  512.3292         B101
# 88          1       1  female  23.0      3      2  263.0000  C23 C25 C27
# 438         0       1    male  64.0      1      4  263.0000  C23 C25 C27
# ..        ...     ...     ...   ...    ...    ...       ...          ...
# 806         0       1    male  39.0      0      0    0.0000          A36
# 815         0       1    male  28.0      0      0    0.0000         B102
# 466         0       2    male  28.0      0      0    0.0000      B96 B98
# 481         0       2    male  28.0      0      0    0.0000      B96 B98
# 822         0       1    male  38.0      0      0    0.0000      B96 B98
#
#     Embarked
# 679        C
# 258        C
# 737        C
# 88         S
# 438        S
# ...

# %% [markdown]
# # Groupby

# %%
titanic.groupby(titanic['Embarked']).size()
titanic['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic.groupby(titanic['Embarked']).size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %%
# Age Distribution
sns.histplot(titanic['Age'],kde=True)
plt.title('Age Distribution')
plt.show()

# %%
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.2f%%', startangle=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Scatter plot

# %%
plt.scatter(titanic['Age'], titanic['Fare'], c=titanic['Survived'], cmap='viridis', alpha=0.7)

# %% [markdown]
# ### PIVOT_TABLE

# %%
pd.pivot_table(titanic,index ='Survived',values=['Age','SibSp','Parch','Fare'])
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.028233  22.117887  0.329690  0.553734
# 1         28.291433  48.395408  0.464912  0.473684

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x='Survived',hue='Sex',data= titanic)
plt.title("Survived by gender (0=N0, 1=Yes)")
# Out:
# Text(0.5, 1.0, 'Survived by gender (0=N0, 1=Yes)')

# %%
sns.barplot(x='Pclass',y='Survived',data=titanic)
plt.title("Survival by Passenger Class")
plt.ylabel('Survival Rate')
plt.xlabel('Passenger Class')
plt.ylim(0,1)
plt.show()

# %%
sns.countplot(x='SibSp',data=titanic)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# ### Displot

# %%
sns.displot(titanic['Age'],color ='orange',bins=40)
plt.show()

# %% [markdown]
# ### Jointplot

# %%
sns.jointplot(x='Age', y='Fare', data=titanic, kind='hex', color='pink')

# %%
sns.jointplot(x='Age', y='Fare', data=titanic, kind='kde', color='pink')

# %%
sns.relplot(x='Parch', y='SibSp', data=titanic, style='Survived')

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x='Fare',y ='Age',data =titanic,hue='Survived', style='Sex', palette='cool', s=120, alpha=0.6)
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.scatterplot(x='Fare', y='Age', data=titanic, color='blue', hue='Survived', style='Pclass', palette='magma', s=100, alpha=0.5)
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.scatterplot(x='Parch', y='SibSp', data=titanic, color='green', hue='Survived', style='Sex', palette='cool', s=120, alpha=0.6)
# Out:
# <Axes: xlabel='Parch', ylabel='SibSp'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic, hue='Survived', palette='Set2')
plt.show()

# %%
# Now Converting categorical data to numeric
titanic['Sex'] = titanic['Sex'].map({'male': 0, 'female': 1})
titanic['Embarked']=titanic['Embarked'].map({'Q':0,'S':1,"C":2})

# %%
titanic.rename(columns={'Embarked': "Port"},inplace=True)

# %%
titanic.drop('Cabin',axis=1,inplace=True)

# %% [markdown]
# ## Correlation

# %%
correleation=titanic.corr()
print(correleation)
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481  0.543351 -0.064910 -0.035322  0.081629
# Pclass   -0.338481  1.000000 -0.131900 -0.339898  0.083081  0.018443
# Sex       0.543351 -0.131900  1.000000 -0.081163  0.114631  0.245489
# Age      -0.064910 -0.339898 -0.081163  1.000000 -0.233296 -0.172482
# SibSp    -0.035322  0.083081  0.114631 -0.233296  1.000000  0.414838
# Parch     0.081629  0.018443  0.245489 -0.172482  0.414838  1.000000
# Fare      0.257307 -0.549500  0.182333  0.096688  0.159651  0.216225
# Port      0.126753 -0.307324  0.023175  0.041031 -0.031095  0.035756
#
#               Fare      Port
# Survived  0.257307  0.126753
# Pclass   -0.549500 -0.307324
# Sex       0.182333  0.023175
# Age       0.096688  0.041031
# SibSp     0.159651 -0.031095
# Parch     0.216225  0.035756
# Fare      1.000000  0.269588
# Port      0.269588  1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(correleation,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### CROSSTAB

# %%
print(pd.crosstab(titanic['Pclass'], titanic['Survived'], normalize='index'))
print(pd.crosstab(titanic['Sex'], titanic['Survived'], normalize='index'))
print(pd.crosstab(titanic['Port'],titanic['Survived'],normalize='index'))
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363
# Survived         0         1
# Sex
# 0         0.811092  0.188908
# 1         0.257962  0.742038
# Survived         0         1
# Port
# 0.0       0.610390  0.389610
# 1.0       0.663043  0.336957
# 2.0       0.446429  0.553571

# %% [markdown]
# ### Now Applying ML models

# %%
X=titanic.drop('Survived',axis=1)
y=titanic['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %% [markdown]
# ### LogisticRegression Model

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
# Check for non-numeric columns
print(X_train.dtypes)

X_train = X_train.dropna()
y_train = y_train.loc[X_train.index]  # align indices

# Fit the model again
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# Pclass      int64
# Sex         int64
# Age       float64
# SibSp       int64
# Parch       int64
# Fare      float64
# Port      float64
# dtype: object
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_test_lr=model_lr.predict(X_test)

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Check for non-numeric columns
print(X_train.dtypes)

# Drop or fill missing values
X_train = X_train.dropna()
y_train = y_train.loc[X_train.index]  # align indices

# Fit the model again
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# Pclass      int64
# Sex         int64
# Age       float64
# SibSp       int64
# Parch       int64
# Fare      float64
# Port      float64
# dtype: object
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model Evalution

# %%
print("Accuarcy Score:",accuracy_score(y_test,y_pred_test_lr))
print("Confussion Matrix: \n",confusion_matrix(y_test,y_pred_test_lr))
print('Classification Report',classification_report(y_test,y_pred_test_lr))
# Out:
# Accuarcy Score: 0.8100558659217877
# Confussion Matrix:
#  [[94 22]
#  [12 51]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85       116
#            1       0.70      0.81      0.75        63
#
#     accuracy                           0.81       179
#    macro avg       0.79      0.81      0.80       179
# weighted avg       0.82      0.81      0.81       179

# %% [markdown]
# #### CONFUSION MATRIX

# %% [markdown]
# ### DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt=DecisionTreeClassifier()
model_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_test_dt=model_dt.predict(X_test)

# %%
# Model Evalution
print("Accuarcy Score:",accuracy_score(y_test,y_pred_test_dt))
print("Confussion Matrix: \n",confusion_matrix(y_test,y_pred_test_dt))
print('Classification Report',classification_report(y_test,y_pred_test_dt))
# Out:
# Accuarcy Score: 0.8044692737430168
# Confussion Matrix:
#  [[90 26]
#  [ 9 54]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       116
#            1       0.68      0.86      0.76        63
#
#     accuracy                           0.80       179
#    macro avg       0.79      0.82      0.80       179
# weighted avg       0.83      0.80      0.81       179

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier()
model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_test_rf=model_rf.predict(X_test)

# %%
# Model Evalution
print("Accuarcy Score:",accuracy_score(y_test,y_pred_test_rf))
print("Confussion Matrix: \n",confusion_matrix(y_test,y_pred_test_rf))
print('Classification Report',classification_report(y_test,y_pred_test_rf))
# Out:
# Accuarcy Score: 0.8156424581005587
# Confussion Matrix:
#  [[90 26]
#  [ 7 56]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85       116
#            1       0.68      0.89      0.77        63
#
#     accuracy                           0.82       179
#    macro avg       0.81      0.83      0.81       179
# weighted avg       0.84      0.82      0.82       179

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict using your trained model
y_pred_rf = model_rf.predict(X_test)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred_rf)

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Not Survived", "Survived"],
            yticklabels=["Not Survived", "Survived"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Random Forest")
plt.show()
